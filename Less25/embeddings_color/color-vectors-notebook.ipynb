# %% [markdown]
# # Colorful Vectors Analysis
#
# This notebook explores color representation in 3D vector space, demonstrating how colors can be represented and compared using their RGB values.

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from functools import lru_cache
import ipywidgets as widgets
from IPython.display import display, clear_output

# Constants
SIZES = [1, 20, 30]
CACHE_SIZE = 32
DEFAULT_COLOR = 'rgb(200,200,200)'  # Added fallback color

# %% [markdown]
# ## Data Loading and Preprocessing
#
# First, let's load and prepare our color data.

# %%
def load_data():
    """Load and preprocess color data."""
    path = "https://frenzy86.s3.eu-west-2.amazonaws.com/python/data/colors.csv"
    df = pd.read_csv(path, names=['simple_name', 'name', 'hex', 'r', 'g', 'b'])
    df['rgb'] = 'rgb(' + df['r'].astype(str) + ',' + df['g'].astype(str) + ',' + df['b'].astype(str) + ')'
    df['category'] = df['simple_name'].str.split('_').str[-1]
    df['size'] = SIZES[0]
    return df

df = load_data()
df.head()
# Out:
#             simple_name                   name      hex    r    g    b  \
# 0    air_force_blue_raf   Air Force Blue (Raf)  #5d8aa8   93  138  168
# 1   air_force_blue_usaf  Air Force Blue (Usaf)  #00308f    0   48  143
# 2  air_superiority_blue   Air Superiority Blue  #72a0c1  114  160  193
# 3       alabama_crimson        Alabama Crimson  #a32638  163   38   56
# 4            alice_blue             Alice Blue  #f0f8ff  240  248  255
#
#                 rgb category  size
# 0   rgb(93,138,168)      raf     1
# 1     rgb(0,48,143)     usaf     1
# 2  rgb(114,160,193)     blue     1
# 3    rgb(163,38,56)  crimson     1
# 4  rgb(240,248,255)     blue     1

# %% [markdown]
# ## Helper Functions
#
# Let's define our utility functions for analysis.

# %%
def get_top_colors(df):
    """Get most common color categories."""
    return [c for c in df['category'].value_counts()[:15].index.tolist()
            if c in df.simple_name.values]

@lru_cache(maxsize=CACHE_SIZE)
def calculate_distances(vector_tuple):
    """Calculate distances between colors."""
    vector = np.array(vector_tuple)
    coords = df[['r', 'g', 'b']].values
    return np.linalg.norm(coords - vector, axis=1)

def build_chart(df_plot):
    """Create 3D scatter plot with optimized layout."""
    if len(df_plot) == 0:
        df_plot = pd.DataFrame({
            'r': [0], 'g': [0], 'b': [0],
            'simple_name': ['No matches'],
            'name': ['No matches'],
            'rgb': [DEFAULT_COLOR],
            'size': [1]
        })

    fig = px.scatter_3d(
        df_plot,
        x='r', y='g', z='b',
        template='plotly_white',
        color='simple_name',
        color_discrete_sequence=df_plot['rgb'].tolist(),
        size='size',
        hover_data=['name']
    )

    fig.update_layout(
        showlegend=False,
        margin=dict(l=5, r=5, t=20, b=5),
        scene=dict(
            xaxis_title="Red",
            yaxis_title="Green",
            zaxis_title="Blue",
            xaxis=dict(range=[0, 255]),
            yaxis=dict(range=[0, 255]),
            zaxis=dict(range=[0, 255])
        )
    )
    return fig

# %% [markdown]
# ## Initial Visualization
#
# Let's visualize all colors in 3D space.

# %%
fig = build_chart(df)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="dbec5bff-5dcc-4c7f-9740-80f87efa0500" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dbec5bff-5dcc-4c7f-9740-80f87efa0500")) {                    Plotly.newPlot(                        "dbec5bff-5dcc-4c7f-9740-80f87efa0500",                        [{"customdata":[["Air Force Blue (Raf)"]],"hovertemplate":"simple_name=air_force_blue_raf\u003cbr\u003er=%{x}\u003cbr\u003eg=%{y}\u003cbr\u003eb=%{z}\u003cbr\u003esize=%{marker.size}\u003cbr\u003ename=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"air_force_blue_raf","marker":{"color":"rgb(93,138,168)","size":[1],"sizemode":"area","sizeref":0.0025,"symbol":"circle"},"mode":"markers","name":"air_force_blue_raf","scene":"scene","showlegend":true,"x":[93],"y":[138],"z":[168],"type":"scatter3d"},{"customdata":[["Air Force Blue (Usaf)"]],"hovertemplate":"simple_name=air_force_blue_usaf\u003cbr\u003er=%{x}\u003cbr\u003eg=%{y}\u003cbr\u003eb=%{z}\u003cbr\u003esize=%{marker.size}\u003cbr\u003ename=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"air_force_blue_usaf","marker":{"color":"rgb(0,48,143)","size":[1],"sizemode":"area","sizeref":0.0025,"symbol":"circle"},"mode":"markers","name":"air_force_blue_usaf","scene":"scene","showlegend":true,"x":[0],"y":[48],"z":[143],"type":"scatter3d"},{"customdata":[["Air Superiority Blue"]],"hovertemplate":"simple_name=air_superiority_blue\u003cbr\u003er=%{x}\u003cbr\u003eg=%{y}\u003cbr\u003eb=%{z}\u003cbr\u003esize=%{marker.size}\u003cbr\u003ename=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"air_superiority_blue","marker":{"color":"rgb(114,160,193)","size":[1],"sizemode":"area","sizeref":0.0025,"symbol":"circle"},"mode":"markers","name":"air_superiority_blue","scene":"scene","showlegend":true,"x":[114],"y":[160],"z":[193],"type":"scatter3d"},{"customdata":[["Alabama Crimson"]],"hovertemplate":"simple_name=alabama_crimson\u003cbr\u003er=%{x}\u003cbr\u003eg=%{y}\u003cbr\u003eb=%{z}\u003cbr\u003esize=%{marker.size}\u003cbr\u003ename=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"alabama_crimson","marker":{"color":"rgb(163,38,56)","size":[1],"sizemode":"area","sizeref":0.0025,"symbol":"circle"},"mode":"markers","name":"alabama_crimson","scene":"scene","showlegend":true,"x":[163],"y":[38],"z":[56],"type":"scatter3d"},{"customdata":[["Alice Blue"]],"hovertemplate":"simple_name=alice_blue\u003cbr\u003er=%{x}\u003cbr\u003eg=%{y}\u003cbr\u003eb=%{z}\u003cbr\u003esize=%{marker.size}\u003cbr\u003ename=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"alice_blue","marker":{"color":"rgb(240,248,255)","size":[1],"sizemode":"area","sizeref":0.0025,"symbol":"circle"},"mode":"markers","name":"alice_blue","scene":"scene","showlegend":true,"x":[240],"y":[248],"z":[255],"type":"scatter3d"},{"customdata":[["Alizarin Crimson"]],"hovertemplate":"simple_name=alizarin_crimson\u003cbr\u003er=%{x}\u003cbr\u003eg=%{y}\u003cbr\u003eb=%{z}\u003cbr\u003esize=%{marker.size}\u003cbr\u003ename=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"alizarin_crimson","marker":{"color":"rgb(227,38,54)","size":[1],"sizemode":"area","sizeref":0.0025,"symbol":"circle"},"mode":"markers","name":"alizarin_crimson","scene":"scene","showlegend":true,"x":[227],"y":[38],"z":[54],"type":"scatter3d"},{"customdata":[["Alloy Orange"]],"hovertemplate":"simple_name=alloy_orange\u003cbr\u003er=%{x}\u003cbr\u003eg=%{y}\u003cbr\u003eb=%{z}\u003cbr\u003esize=%{marker.size}\u003cbr\u003ename=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"alloy_orange","marker":{"color":"rgb(196,98,16)","size":[1],"sizemode":"area","sizeref":0.0025,"s ...

# %% [markdown]
# ## Color Search Comparison
#
# Let's compare text-based search vs. vector-based search for colors.

# %%
# Get top colors for selection
top_colors = get_top_colors(df)
print("Available colors for analysis:", top_colors)
# Out:
# Available colors for analysis: ['blue', 'pink', 'red', 'yellow', 'rose', 'gray', 'magenta', 'violet']

# %%
def compare_search_methods(query, thresh_sel):
    match = df[df.simple_name == query].iloc[0]

    # Text-based search
    text_matches = df[df.simple_name.str.contains(query, case=False)].copy()
    if len(text_matches) > 0:
        text_matches['size'] = SIZES[1]
        text_matches.loc[text_matches.simple_name == query, 'size'] = SIZES[2]

    # Vector-based search
    distances = calculate_distances(tuple(match[['r', 'g', 'b']].values))
    vector_matches = df[distances < thresh_sel].copy()
    if len(vector_matches) > 0:
        vector_matches['size'] = SIZES[1]
        vector_matches.loc[vector_matches.simple_name == query, 'size'] = SIZES[2]

    # Display results
    fig1 = build_chart(text_matches)
    fig2 = build_chart(vector_matches)

    clear_output(wait=True)
    print(f"\nResults for color: {query} ({match.r}, {match.g}, {match.b})")
    print(f"Text-based matches: {len(text_matches)}")
    print(f"Vector-based matches: {len(vector_matches)}")
    display(fig1)
    display(fig2)

    return text_matches, vector_matches

# %%
# Load data
df = load_data()
DEFAULT_THRESHOLD = 80

# Create interactive widgets
threshold_slider = widgets.IntSlider(
                                    value=DEFAULT_THRESHOLD,
                                    min=20,
                                    max=100,
                                    step=1,
                                    description='Threshold:',
                                    style={'description_width': 'initial'}
                                    )
threshold_slider
# Out:
# IntSlider(value=80, description='Threshold:', min=20, style=SliderStyle(description_width='initial'))

# %%
# Example analysis with 'red'
def on_threshold_change(change):
    compare_search_methods('red', change.new)

threshold_slider.observe(on_threshold_change, names='value')
display(threshold_slider)

# Initial comparison
compare_search_methods('red', DEFAULT_THRESHOLD)
# Out:
# Results for color: red (255, 0, 0)
# Text-based matches: 51
# Vector-based matches: 37
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="eee44a66-c1f6-43f7-a77d-aebe78208c8c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eee44a66-c1f6-43f7-a77d-aebe78208c8c")) {                    Plotly.newPlot(                        "eee44a66-c1f6-43f7-a77d-aebe78208c8c",                        [{"customdata":[["Barn Red"]],"hovertemplate":"simple_name=barn_red\u003cbr\u003er=%{x}\u003cbr\u003eg=%{y}\u003cbr\u003eb=%{z}\u003cbr\u003esize=%{marker.size}\u003cbr\u003ename=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"barn_red","marker":{"color":"rgb(124,10,2)","size":[20],"sizemode":"area","sizeref":0.075,"symbol":"circle"},"mode":"markers","name":"barn_red","scene":"scene","showlegend":true,"x":[124],"y":[10],"z":[2],"type":"scatter3d"},{"customdata":[["Boston University Red"]],"hovertemplate":"simple_name=boston_university_red\u003cbr\u003er=%{x}\u003cbr\u003eg=%{y}\u003cbr\u003eb=%{z}\u003cbr\u003esize=%{marker.size}\u003cbr\u003ename=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"boston_university_red","marker":{"color":"rgb(204,0,0)","size":[20],"sizemode":"area","sizeref":0.075,"symbol":"circle"},"mode":"markers","name":"boston_university_red","scene":"scene","showlegend":true,"x":[204],"y":[0],"z":[0],"type":"scatter3d"},{"customdata":[["Brick Red"]],"hovertemplate":"simple_name=brick_red\u003cbr\u003er=%{x}\u003cbr\u003eg=%{y}\u003cbr\u003eb=%{z}\u003cbr\u003esize=%{marker.size}\u003cbr\u003ename=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"brick_red","marker":{"color":"rgb(203,65,84)","size":[20],"sizemode":"area","sizeref":0.075,"symbol":"circle"},"mode":"markers","name":"brick_red","scene":"scene","showlegend":true,"x":[203],"y":[65],"z":[84],"type":"scatter3d"},{"customdata":[["Cadmium Red"]],"hovertemplate":"simple_name=cadmium_red\u003cbr\u003er=%{x}\u003cbr\u003eg=%{y}\u003cbr\u003eb=%{z}\u003cbr\u003esize=%{marker.size}\u003cbr\u003ename=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"cadmium_red","marker":{"color":"rgb(227,0,34)","size":[20],"sizemode":"area","sizeref":0.075,"symbol":"circle"},"mode":"markers","name":"cadmium_red","scene":"scene","showlegend":true,"x":[227],"y":[0],"z":[34],"type":"scatter3d"},{"customdata":[["Candy Apple Red"]],"hovertemplate":"simple_name=candy_apple_red\u003cbr\u003er=%{x}\u003cbr\u003eg=%{y}\u003cbr\u003eb=%{z}\u003cbr\u003esize=%{marker.size}\u003cbr\u003ename=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"candy_apple_red","marker":{"color":"rgb(255,8,0)","size":[20],"sizemode":"area","sizeref":0.075,"symbol":"circle"},"mode":"markers","name":"candy_apple_red","scene":"scene","showlegend":true,"x":[255],"y":[8],"z":[0],"type":"scatter3d"},{"customdata":[["Carmine Red"]],"hovertemplate":"simple_name=carmine_red\u003cbr\u003er=%{x}\u003cbr\u003eg=%{y}\u003cbr\u003eb=%{z}\u003cbr\u003esize=%{marker.size}\u003cbr\u003ename=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"carmine_red","marker":{"color":"rgb(255,0,56)","size":[20],"sizemode":"area","sizeref":0.075,"symbol":"circle"},"mode":"markers","name":"carmine_red","scene":"scene","showlegend":true,"x":[255],"y":[0],"z":[56],"type":"scatter3d"},{"customdata":[["Cg Red"]],"hovertemplate":"simple_name=cg_red\u003cbr\u003er=%{x}\u003cbr\u003eg=%{y}\u003cbr\u003eb=%{z}\u003cbr\u003esize=%{marker.size}\u003cbr\u003ename=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"cg_red","marker":{"color":"rgb(224,60,49)","size":[20],"sizemode":"area","sizeref":0.075,"symbol":"circle"},"mode":"markers","name":"cg_red","scene":"scene","showlegend":true,"x":[224],"y":[60],"z":[49],"type":"scatter3d"},{"cu ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6c82235c-24a4-43d7-a6b9-32d3281fd175" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c82235c-24a4-43d7-a6b9-32d3281fd175")) {                    Plotly.newPlot(                        "6c82235c-24a4-43d7-a6b9-32d3281fd175",                        [{"customdata":[["Alizarin Crimson"]],"hovertemplate":"simple_name=alizarin_crimson\u003cbr\u003er=%{x}\u003cbr\u003eg=%{y}\u003cbr\u003eb=%{z}\u003cbr\u003esize=%{marker.size}\u003cbr\u003ename=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"alizarin_crimson","marker":{"color":"rgb(227,38,54)","size":[20],"sizemode":"area","sizeref":0.075,"symbol":"circle"},"mode":"markers","name":"alizarin_crimson","scene":"scene","showlegend":true,"x":[227],"y":[38],"z":[54],"type":"scatter3d"},{"customdata":[["American Rose"]],"hovertemplate":"simple_name=american_rose\u003cbr\u003er=%{x}\u003cbr\u003eg=%{y}\u003cbr\u003eb=%{z}\u003cbr\u003esize=%{marker.size}\u003cbr\u003ename=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"american_rose","marker":{"color":"rgb(255,3,62)","size":[20],"sizemode":"area","sizeref":0.075,"symbol":"circle"},"mode":"markers","name":"american_rose","scene":"scene","showlegend":true,"x":[255],"y":[3],"z":[62],"type":"scatter3d"},{"customdata":[["Boston University Red"]],"hovertemplate":"simple_name=boston_university_red\u003cbr\u003er=%{x}\u003cbr\u003eg=%{y}\u003cbr\u003eb=%{z}\u003cbr\u003esize=%{marker.size}\u003cbr\u003ename=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"boston_university_red","marker":{"color":"rgb(204,0,0)","size":[20],"sizemode":"area","sizeref":0.075,"symbol":"circle"},"mode":"markers","name":"boston_university_red","scene":"scene","showlegend":true,"x":[204],"y":[0],"z":[0],"type":"scatter3d"},{"customdata":[["Cadmium Red"]],"hovertemplate":"simple_name=cadmium_red\u003cbr\u003er=%{x}\u003cbr\u003eg=%{y}\u003cbr\u003eb=%{z}\u003cbr\u003esize=%{marker.size}\u003cbr\u003ename=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"cadmium_red","marker":{"color":"rgb(227,0,34)","size":[20],"sizemode":"area","sizeref":0.075,"symbol":"circle"},"mode":"markers","name":"cadmium_red","scene":"scene","showlegend":true,"x":[227],"y":[0],"z":[34],"type":"scatter3d"},{"customdata":[["Candy Apple Red"]],"hovertemplate":"simple_name=candy_apple_red\u003cbr\u003er=%{x}\u003cbr\u003eg=%{y}\u003cbr\u003eb=%{z}\u003cbr\u003esize=%{marker.size}\u003cbr\u003ename=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"candy_apple_red","marker":{"color":"rgb(255,8,0)","size":[20],"sizemode":"area","sizeref":0.075,"symbol":"circle"},"mode":"markers","name":"candy_apple_red","scene":"scene","showlegend":true,"x":[255],"y":[8],"z":[0],"type":"scatter3d"},{"customdata":[["Carmine (M&P)"]],"hovertemplate":"simple_name=carmine_m_p\u003cbr\u003er=%{x}\u003cbr\u003eg=%{y}\u003cbr\u003eb=%{z}\u003cbr\u003esize=%{marker.size}\u003cbr\u003ename=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"carmine_m_p","marker":{"color":"rgb(215,0,64)","size":[20],"sizemode":"area","sizeref":0.075,"symbol":"circle"},"mode":"markers","name":"carmine_m_p","scene":"scene","showlegend":true,"x":[215],"y":[0],"z":[64],"type":"scatter3d"},{"customdata":[["Carmine Red"]],"hovertemplate":"simple_name=carmine_red\u003cbr\u003er=%{x}\u003cbr\u003eg=%{y}\u003cbr\u003eb=%{z}\u003cbr\u003esize=%{marker.size}\u003cbr\u003ename=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"carmine_red","marker":{"color":"rgb(255,0,56)","size":[20],"sizemode":"area","sizeref":0.075,"symbol":"circle"},"mode":"markers","name":"carmine_red","scene":"scene"," ...
# (                simple_name                    name      hex    r    g    b  \
#  42                 barn_red                Barn Red  #7c0a02  124   10    2
#  77    boston_university_red   Boston University Red     #c00  204    0    0
#  82                brick_red               Brick Red  #cb4154  203   65   84
#  113             cadmium_red             Cadmium Red  #e30022  227    0   34
#  123         candy_apple_red         Candy Apple Red  #ff0800  255    8    0
#  132             carmine_red             Carmine Red  #ff0038  255    0   56
#  150                  cg_red                  Cg Red  #e03c31  224   60   49
#  162             chinese_red             Chinese Red  #aa381e  170   56   30
#  181              copper_red              Copper Red  #cb6d51  203  109   81
#  186               coral_red               Coral Red  #ff4040  255   64   64
#  189             cornell_red             Cornell Red  #b31b1b  179   27   27
#  204    dark_candy_apple_red    Dark Candy Apple Red  #a40000  164    0    0
#  226         dark_pastel_red         Dark Pastel Red  #c23b22  194   59   34
#  230                dark_red                Dark Red  #8b0000  139    0    0
#  247              debian_red              Debian Red  #d70a53  215   10   83
#  264         deep_tuscan_red         Deep Tuscan Red  #66424d  102   66   77
#  295                falu_red                Falu Red  #801818  128   24   24
#  301             ferrari_red             Ferrari Red  #ff2800  255   40    0
#  303         fire_engine_red         Fire Engine Red  #ce2029  206   32   41
#  376              indian_red              Indian Red  #cd5c5c  205   92   92
#  439         light_red_ochre         Light Red Ochre  #e97451  233  116   81
#  482  medium_candy_apple_red  Medium Candy Apple Red  #e2062c  226    6   44
#  491       medium_red_violet       Medium Red-Violet  #bb3385  187   51  133
#  499       medium_tuscan_red       Medium Tuscan Red  #79443b  121   68   59
#  501       medium_violet_red       Medium Violet-Red  #c71585  199   21  133
#  515          mordant_red_19          Mordant Red 19  #ae0c00  174   12    0
#  550              orange_red              Orange-Red  #ff4500  255   69    0
#  555          ou_crimson_red          Ou Crimson Red     #900  153    0    0
#  577         pale_red_violet         Pale Red-Violet  #db7093  219  112  147
#  582         pale_violet_red         Pale Violet-Red  #db7093  219  112  147
#  594              pastel_red              Pastel Red  #ff6961  255  105   97
#  616             persian_red             Persian Red     #c33  204   51   51
#  651             radical_red             Radical Red  #ff355e  255   53   94
#  660                     red                     Red     #f00  255    0    0
#  661               red_brown               Red-Brown  #a52a2a  165   42   42
#  662               red_devil               Red Devil  #860111  134    1   17
#  663             red_munsell           Red (Munsell)  #f2003c  242    0   60
#  664                 red_ncs               Red (Ncs)  #c40233  196    2   51
#  665              red_orange              Red-Orange  #ff5349  255   83   73
#  666             red_pigment           Red (Pigment)  #ed1c24  237   28   36
#  667                 red_ryb               Red (Ryb)  #fe2712  254   39   18
#  668              red_violet              Red-Violet  #c71585  199   21  133
#  669                 redwood                 Redwood  #ab4e52  171   78   82
#  699              rubine_red              Rubine Red  #d10056  209    0   86
#  701                ruby_red                Ruby Red  #9b111e  155   17   30
#  708               rusty_red               Rusty Red  #da2c43  218   44   67
#  788             tractor_red             Tractor Red  #fd0e35  253   14   53
#  798              tuscan_red              Tuscan Red  #7c4848  124   72   72
#  802                  ua_red                  Ua Red  #d9004c  217    0   76
#  817             upsdell_red             Upsdell Red  #ae2029  174   32   41
#  825            venetian_red            Venetian Red  #c80815  200    8   21
#
#                    rgb category  size
#  42      rgb(124,10,2)      red    20
#  77       rgb(204,0,0)      red    20
#  82     rgb(203,65,84)      red    20
#  113     rgb(227,0,34)      red    20
#  123      rgb(255,8,0)      red    20
#  132     rgb(255,0,56)      red    20
#  150    rgb(224,60,49)      red    20
#  162    rgb(170,56,30)      red    20
#  181   rgb(203,109,81)      red    20
#  186    rgb(255,64,64)      red    20
#  189    rgb(179,27,27)      red    20
#  204      rgb(164,0,0)      red    20
#  226    rgb(194,59,34)      red    20
#  230      rgb(139,0,0)      red    20
#  247    rgb(215,10,83)      red    20
#  264    rgb(102,66,77)      red    20
#  295    rgb(128,24,24)      red    20
#  301     rgb(255,40,0)      red    20
#  303    rgb(206,32,41)      red    20
#  376    rgb(205,92,92)      red    20
#  439   rgb(233,116,81)    ochre    20
#  482     rgb(226,6,44)      red    20
#  491   rgb(187,51,133)   violet    20
#  499    rgb(121,68,59)      red    20
#  501   rgb(199,21,133)      red    20
#  515     rgb(174,12,0)       19    20
#  550     rgb(255,69,0)      red    20
#  555      rgb(153,0,0)      red    20
#  577  rgb(219,112,147)   violet    20
#  582  rgb(219,112,147)      red    20
#  594   rgb(255,105,97)      red    20
#  616    rgb(204,51,51)      red    20
#  651    rgb(255,53,94)      red    20
#  660      rgb(255,0,0)      red    30
#  661    rgb(165,42,42)    brown    20
#  662     rgb(134,1,17)    devil    20
#  663     rgb(242,0,60)  munsell    20
#  664     rgb(196,2,51)      ncs    20
#  665    rgb(255,83,73)   orange    20
#  666    rgb(237,28,36)  pigment    20
#  667    rgb(254,39,18)      ryb    20
#  668   rgb(199,21,133)   violet    20
#  669    rgb(171,78,82)  redwood    20
#  699     rgb(209,0,86)      red    20
#  701    rgb(155,17,30)      red    20
#  708    rgb(218,44,67)      red    20
#  788    rgb(253,14,53)      red    20
#  798    rgb(124,72,72)      red    20
#  802     rgb(217,0,76)      red    20
#  817    rgb(174,32,41)      red    20
#  825     rgb(200,8,21)      red    20  ,
#                            simple_name                                name  \
#  5                    alizarin_crimson                    Alizarin Crimson
#  11                      american_rose                       American Rose
#  77              boston_university_red               Boston University Red
#  113                       cadmium_red                         Cadmium Red
#  123                   candy_apple_red                     Candy Apple Red
#  130                       carmine_m_p                       Carmine (M&P)
#  132                       carmine_red                         Carmine Red
#  183                        coquelicot                          Coquelicot
#  195                           crimson                             Crimson
#  249                 deep_carmine_pink                   Deep Carmine Pink
#  281                  electric_crimson                    Electric Crimson
#  301                       ferrari_red                         Ferrari Red
#  303                   fire_engine_red                     Fire Engine Red
#  313                             folly                               Folly
#  360                   harvard_crimson                     Harvard Crimson
#  382    international_orange_aerospace    International Orange (Aerospace)
#  383  international_orange_engineering  International Orange (Engineering)
#  401                        ku_crimson                          Ku Crimson
#  407                              lava                                Lava
#  458                              lust                                Lust
#  482            medium_candy_apple_red              Medium Candy Apple Red
#  550                        orange_red                          Orange-Red
#  660                               red                                 Red
#  663                       red_munsell                       Red (Munsell)
#  664                           red_ncs                           Red (Ncs)
#  666                       red_pigment                       Red (Pigment)
#  667                           red_ryb                           Red (Ryb)
#  674                      rich_carmine                        Rich Carmine
#  685                       rose_madder                         Rose Madder
#  691                       rosso_corsa                         Rosso Corsa
#  702                             ruddy                               Ruddy
#  725                           scarlet                             Scarlet
#  726                   scarlet_crayola                   Scarlet (Crayola)
#  763                           tangelo                             Tangelo
#  788                       tractor_red                         Tractor Red
#  822                      utah_crimson                        Utah Crimson
#  825                      venetian_red                        Venetian Red
#
#           hex    r   g   b             rgb     category  size
#  5    #e32636  227  38  54  rgb(227,38,54)      crimson    20
#  11   #ff033e  255   3  62   rgb(255,3,62)         rose    20
#  77      #c00  204   0   0    rgb(204,0,0)          red    20
#  113  #e30022  227   0  34   rgb(227,0,34)          red    20
#  123  #ff0800  255   8   0    rgb(255,8,0)          red    20
#  130  #d70040  215   0  64   rgb(215,0,64)            p    20
#  132  #ff0038  255   0  56   rgb(255,0,56)          red    20
#  183  #ff3800  255  56   0   rgb(255,56,0)   coquelicot    20
#  195  #dc143c  220  20  60  rgb(220,20,60)      crimson    20
#  249  #ef3038  239  48  56  rgb(239,48,56)         pink    20
#  281  #ff003f  255   0  63   rgb(255,0,63)      crimson    20
#  301  #ff2800  255  40   0   rgb(255,40,0)          red    20
#  303  #ce2029  206  32  41  rgb(206,32,41)          red    20
#  313  #ff004f  255   0  79   rgb(255,0,79)        folly    20
#  360  #c90016  201   0  22   rgb(201,0,22)      crimson    20
#  382  #ff4f00  255  79   0   rgb(255,79,0)    aerospace    20
#  383  #ba160c  186  22  12  rgb(186,22,12)  engineering    20
#  401  #e8000d  232   0  13   rgb(232,0,13)      crimson    20
#  407  #cf1020  207  16  32  rgb(207,16,32)         lava    20
#  458  #e62020  230  32  32  rgb(230,32,32)         lust    20
#  482  #e2062c  226   6  44   rgb(226,6,44)          red    20
#  550  #ff4500  255  69   0   rgb(255,69,0)          red    20
#  660     #f00  255   0   0    rgb(255,0,0)          red    30
#  663  #f2003c  242   0  60   rgb(242,0,60)      munsell    20
#  664  #c40233  196   2  51   rgb(196,2,51)          ncs    20
#  666  #ed1c24  237  28  36  rgb(237,28,36)      pigment    20
#  667  #fe2712  254  39  18  rgb(254,39,18)          ryb    20
#  674  #d70040  215   0  64   rgb(215,0,64)      carmine    20
#  685  #e32636  227  38  54  rgb(227,38,54)       madder    20
#  691  #d40000  212   0   0    rgb(212,0,0)        corsa    20
#  702  #ff0028  255   0  40   rgb(255,0,40)        ruddy    20
#  725  #ff2400  255  36   0   rgb(255,36,0)      scarlet    20
#  726  #fd0e35  253  14  53  rgb(253,14,53)      crayola    20
#  763  #f94d00  249  77   0   rgb(249,77,0)      tangelo    20
#  788  #fd0e35  253  14  53  rgb(253,14,53)          red    20
#  822  #d3003f  211   0  63   rgb(211,0,63)      crimson    20
#  825  #c80815  200   8  21   rgb(200,8,21)          red    20  )

# %% [markdown]
# ## Analysis and Conclusions
#
# The vector-based search demonstrates several advantages over text-based search:
#
# 1. It finds similar colors regardless of their names
# 2. Results are based on objective color properties rather than naming conventions
# 3. The similarity threshold can be adjusted to find more or fewer matches
#
# This simple example illustrates why vector representations are powerful: they enable objective similarity comparisons based on inherent properties rather than arbitrary labels.
